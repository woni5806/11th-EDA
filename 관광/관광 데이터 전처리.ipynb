# %%
# 코랩에서 작성할 경우
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 리셋

# %%
final_data = pd.DataFrame(columns = ['Latitude', 'Longitude'])
final_data
# Out:
# Empty DataFrame
# Columns: [Latitude, Longitude]
# Index: []

# %% [markdown]
# ### 먹자골목

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/먹자골목.csv')

# %%
data.head()
# Out:
#       FCLTY_NM          RDNMADR_NM  CTPRVN_CD  SIGNGU_CD    FCLTY_LO  \
# 0    강릉병산옹심이골목         강원도 강릉시 병산동       42.0    42150.0  128.944649
# 1      아바이순대타운  강원도 속초시 금호동 492-51       42.0    42210.0  128.589145
# 2  학사평콩꽃마을순두부촌         강원도 속초시 노학동       42.0    42210.0  128.529887
# 3    대포항원조튀김골목         강원도 속초시 대포동       42.0    42210.0  128.599662
# 4      새우튀김 골목     강원도 속초시 대포동 965       42.0    42210.0  128.607378
#
#     FCLTY_LA AREA_NM NEARBY_PBTRNSP_NM PARKNG_POSBL_AT   BASE_DE
# 0  37.759655      강원               자루뫼               유  20211231
# 1  38.204664      강원            관광수산시장               유  20211231
# 2  38.190603      강원             원암로입구               유  20211231
# 3  38.174195      강원             대포항입구               유  20211231
# 4  38.174254      강원             대포항입구               유  20211231

# %%
data['Latitude'] = data['FCLTY_LA']
data['Longitude'] = data['FCLTY_LO']
data[['Latitude', 'Longitude']]
# Out:
#       Latitude   Longitude
# 0    37.759655  128.944649
# 1    38.204664  128.589145
# 2    38.190603  128.529887
# 3    38.174195  128.599662
# 4    38.174254  128.607378
# ..         ...         ...
# 514  37.478525  126.977939
# 515  37.267371  127.000746
# 516  37.592665  126.920521
# 517  35.836875  128.575176
# 518  35.882503  128.618996
#
# [519 rows x 2 columns]

# %% [markdown]
# ### 잘 적용됐는지 확인

# %%
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#       Latitude   Longitude
# 0    37.759655  128.944649
# 1    38.204664  128.589145
# 2    38.190603  128.529887
# 3    38.174195  128.599662
# 4    38.174254  128.607378
# ..         ...         ...
# 514  37.478525  126.977939
# 515  37.267371  127.000746
# 516  37.592665  126.920521
# 517  35.836875  128.575176
# 518  35.882503  128.618996
#
# [519 rows x 2 columns]

# %% [markdown]
# ### 티비에 나온거

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/RB_RESTAURANT_INTRODUCED_ON_TV_INFO_20211231.csv')
data.head()
# Out:
#      FCLTY_NM             RDNMADR_NM  CTPRVN_CD SIGNGU_CD   FCLTY_LO  \
# 0       고성막국수  서울특별시 강서구 방화대로49길 6-7       11.0     126.8  37.577455
# 1  강촌숯불닭갈비 본점  서울특별시 구로구 공원로6나길 35-2       11.0     126.8  37.504430
# 2          덕원    서울특별시 영등포구 버드나루로길 6       11.0     126.8  37.526413
# 3        길풍식당   서울특별시특별시 영등포구 양평로 85       11.0     126.9  37.566415
# 4         대관원    서울특별시 영등포구 당산로37길 1       11.0     126.8  37.529420
#
#     FCLTY_LA AREA_NM HMPG_URL  TEL_NO REPRSNT_MENU_NM MENU_PRC   BASE_DE
# 0  37.577455      서울      NaN     NaN            물막국수     7000  20211231
# 1  37.504430      서울      NaN     NaN       양념 숯불 닭갈비    11000  20211231
# 2  37.526413      서울      NaN     NaN            꼬리곰탕     9000  20211231
# 3  37.535920      서울      NaN     NaN             꼬리탕    20000  20211231
# 4  37.529420      서울      NaN     NaN           삼선간짜장     8000  20211231

# %%
data['Latitude'] = data['FCLTY_LA']
data['Longitude'] = data['FCLTY_LO']
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#       Latitude   Longitude
# 0    37.759655  128.944649
# 1    38.204664  128.589145
# 2    38.190603  128.529887
# 3    38.174195  128.599662
# 4    38.174254  128.607378
# ..         ...         ...
# 733  37.540742  130.874599
# 734  38.109951  127.986286
# 735  36.451265  127.134333
# 736  37.564124  126.983912
# 737  37.563182  127.015087
#
# [1257 rows x 2 columns]

# %% [markdown]
# ### PALACE

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/RB_PALACE_RESTAURANT_INFO_20211231.csv')
data.head()
# Out:
#   FLAG_NM FCLTY_NM                  RDNMADR_NM  CTPRVN_CD  SIGNGU_CD  \
# 0   템플스테이      영평사        세종특별자치시 장군면 영평사길 124        NaN        NaN
# 1   사찰음식점      일월정     대구광역시 달성군 논공읍 논공로 697-5       27.0    27710.0
# 2   템플스테이      선운사  전라북도 고창군 아산면 선운사로 250(선운사)       45.0    45790.0
# 3   궁중음식점   단원 한정식        경기도 안산시 단원구 광덕대로 251       41.0    41273.0
# 4   템플스테이      건봉사        강원도 고성군 거진읍 건봉사로 723       42.0    42820.0
#
#      FCLTY_LO   FCLTY_LA AREA_NM  \
# 0  127.227574  36.472840      세종
# 1  128.451691  35.730642      대구
# 2  126.578075  35.496939      전북
# 3  126.829881  37.319155      경기
# 4  128.379259  38.402208      강원
#
#                                             HMPG_URL  TEL_NO  \
# 0      http://kb5.templestay.com/index.asp?t_id=ypsa     NaN
# 1                     https://blog.naver.com/jjy9148     NaN
# 2    http://kb3.templestay.com/index.asp?t_id=sg9893     NaN
# 3                       http://www.seokparang.co.kr/     NaN
# ...

# %%
data['Latitude'] = data['FCLTY_LA']
data['Longitude'] = data['FCLTY_LO']
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#       Latitude   Longitude
# 0    37.759655  128.944649
# 1    38.204664  128.589145
# 2    38.190603  128.529887
# 3    38.174195  128.599662
# 4    38.174254  128.607378
# ..         ...         ...
# 251  37.509779  127.125774
# 252  37.579407  126.989116
# 253  37.571759  126.986233
# 254  37.583563  126.989214
# 255  37.381656  126.830567
#
# [1513 rows x 2 columns]

# %% [markdown]
# ### Michelin

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/RB_MICHELIN_SLCTN_RSTRNT_INFO_20211231.csv')
data.head()
# Out:
#   MICHELIN_NM FCLTY_NM                 RDNMADR_NM AREA_NM  \
# 0    더플레이트미쉐린      류니끄     서울특별시 강남구 강남대로 162길 40      서울
# 1        빕구르망      현우동      서울특별시 강남구 논현로 149길 53      서울
# 2    더플레이트미쉐린      미토우  서울특별시 강남구 논현로 151길 17, 2층      서울
# 3    더플레이트미쉐린     쿠시카와       서울특별시 강남구 논현로 24길 37      서울
# 4     1스타 미쉐린       에빗       서울특별시 강남구 도곡로 23길 33      서울
#
#                    CTPRVN_ENG_NM SIGNGU_ENGL_NM CTPRVN_JLANG_NM  \
# 0  Seoul Metropolitan Government     Gangnam-gu          ソウル特別市
# 1  Seoul Metropolitan Government     Gangnam-gu          ソウル特別市
# 2  Seoul Metropolitan Government     Gangnam-gu          ソウル特別市
# 3  Seoul Metropolitan Government     Gangnam-gu          ソウル特別市
# 4  Seoul Metropolitan Government     Gangnam-gu          ソウル特別市
#
#   SIGNGU_JLANG_NM CTPRVN_SIMCH_CHNLNG_NM SIGNGU_SIMCH_CHNLNG_NM  \
# 0             江南?                  首?特?市                    江南?
# 1             江南?                  首?特?市                    江南?
# ...

# %%
data['Latitude'] = data['FCLTY_LA']
data['Longitude'] = data['FCLTY_LO']
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#       Latitude   Longitude
# 0    37.759655  128.944649
# 1    38.204664  128.589145
# 2    38.190603  128.529887
# 3    38.174195  128.599662
# 4    38.174254  128.607378
# ..         ...         ...
# 183  37.560360  126.997000
# 184  37.561963  126.988596
# 185  37.521378  127.031686
# 186  37.554996  126.924117
# 187  37.545335  126.984434
#
# [1701 rows x 2 columns]

# %% [markdown]
# ### 관광 탑 100

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/RB_KOREA_TOUR_TOP100_2019_2020_INFO_20211231.csv')
data.head()
# Out:
#        FCLTY_NM              RDNMADR_NM  CTPRVN_CD  SIGNGU_CD    FCLTY_LO  \
# 0        강릉 주문진            강원도 강릉시 주문진읍       42.0    42150.0  128.762225
# 1       강릉 커피거리    강원도 강릉시 창해로14번길 20-1       42.0    42150.0  128.947334
# 2  고성 DMZ 평화관광지    강원도 고성군 현내면 금강산로 481       42.0    42820.0  128.417183
# 3    삼척 대이리동굴지대  강원도 삼척시 신기면 대이리 대이동굴지대       42.0    42230.0  129.025529
# 4    원주 소금산출렁다리     강원도 원주시 지정면 소금산길 14       42.0    42130.0  127.833656
#
#     FCLTY_LA AREA_NM CTPRVN_JLANG_NM SIGNGU_JLANG_NM  \
# 0  37.886676      강원             江原道             江陵市
# 1  37.772590      강원             江原道             江陵市
# 2  38.514453      강원             江原道             高城郡
# 3  37.327291      강원             江原道             三陟市
# 4  37.364653      강원             江原道             原州市
#
#                           HMPG_URL  TEL_NO NEARBY_SUBWAYST_NM   BASE_DE
# 0                              NaN     NaN             주문진항입구  20211231
# ...

# %%
data['Latitude'] = data['FCLTY_LA']
data['Longitude'] = data['FCLTY_LO']
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#       Latitude   Longitude
# 0    37.759655  128.944649
# 1    38.204664  128.589145
# 2    38.190603  128.529887
# 3    38.174195  128.599662
# 4    38.174254  128.607378
# ..         ...         ...
# 223  35.907587  127.065953
# 224  35.908301  127.068085
# 225  35.739837  127.132355
# 226  35.988448  127.241980
# 227  35.988448  127.241980
#
# [1929 rows x 2 columns]

# %% [markdown]
# ### 쇼핑몰

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/KC_506_DMSTC_MCST_SHOPNG_2023.csv')
data.head()
# Out:
#                     ID LCLAS_NM MLSFC_NM  POI_ID POI_NM BHF_NM  ASSTN_NM  \
# 0  KCSHOPO23N000000001       장소       쇼핑    5362    진마트    NaN       NaN
# 1  KCSHOPO23N000000002       장소       쇼핑   92875    빅마트    NaN       NaN
# 2  KCSHOPO23N000000003       장소       쇼핑  127577   마트뱅크    NaN       NaN
# 3  KCSHOPO23N000000004       장소       쇼핑  136386   여수마트    NaN       NaN
# 4  KCSHOPO23N000000005       장소       쇼핑  136438    진마트    NaN       NaN
#
#    CL_CD   CL_NM                  PNU  ...    RDNMADR_CD RDNMADR_NM BULD_NO  \
# 0  91205  지역할인매장  4812532024104170000  ...  4.812523e+11     삼진의거대로     624
# 1  91205  지역할인매장  3111010300105010006  ...  3.111043e+11       학성4길      58
# 2  91205  지역할인매장  4817012000100750001  ...  4.817048e+11   상대로143번길      24
# 3  91205  지역할인매장  4613012200106730002  ...  4.613046e+11       미평9길      17
# 4  91205  지역할인매장  4874038021102170001  ...  4.874033e+11      영산장마로     753
#
#         LC_LO      LC_LA    GID_CD  LAST_CHG_DE  ORIGIN_NM  \
# ...

# %%
data['Latitude'] = data['LC_LA']
data['Longitude'] = data['LC_LO']
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#        Latitude   Longitude
# 0     37.759655  128.944649
# 1     38.204664  128.589145
# 2     38.190603  128.529887
# 3     38.174195  128.599662
# 4     38.174254  128.607378
# ...         ...         ...
# 8456  37.013139  127.113586
# 8457  35.075108  128.068419
# 8458  37.528995  126.708933
# 8459  35.976150  126.744999
# 8460  36.902725  127.533281
#
# [10390 rows x 2 columns]

# %% [markdown]
# ### LLR Attraction

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/KC_495_LLR_ATRCTN_2023.csv')
data.head()
# Out:
#                     ID LCLAS_NM MLSFC_NM  POI_ID   POI_NM BHF_NM  ASSTN_NM  \
# 0  KCLANPO23N000000001       장소      관광지   76838    간절곶등대    NaN       NaN
# 1  KCLANPO23N000000002       장소      관광지  141502  우성항공여행사    NaN       NaN
# 2  KCLANPO23N000000003       장소      관광지  142394    우정여행사    NaN       NaN
# 3  KCLANPO23N000000004       장소      관광지  145432  비산항공여행사    NaN       NaN
# 4  KCLANPO23N000000005       장소      관광지  149376    부래여행사    NaN       NaN
#
#    CL_CD    CL_NM                  PNU  ...    RDNMADR_CD RDNMADR_NM BULD_NO  \
# 0  60513    일반관광지  3171031025100280001  ...  3.171043e+11      간절곶1길    39-2
# 1  60403  항공사/여행사  4579025021102250000  ...  4.579033e+11        중앙로     232
# 2  60403  항공사/여행사  1114010300100310023  ...  1.114041e+11    세종대로20길      15
# 3  60403  항공사/여행사  1165010700100520006  ...  1.165031e+11      서초중앙로     225
# 4  60403  항공사/여행사  2611010700100550001  ...  2.611031e+11        해관로      76
#
# ...

# %%
data['Latitude'] = data['LC_LA']
data['Longitude'] = data['LC_LO']
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#         Latitude   Longitude
# 0      37.759655  128.944649
# 1      38.204664  128.589145
# 2      38.190603  128.529887
# 3      38.174195  128.599662
# 4      38.174254  128.607378
# ...          ...         ...
# 51475  37.391000  129.230584
# 51476  36.358874  129.391512
# 51477  37.483544  126.926914
# 51478  35.154344  129.057691
# 51479  37.209344  127.006585
#
# [61870 rows x 2 columns]

# %% [markdown]
# ### 카페

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/KC_493_DMSTC_MCST_CAFE_DSRT_2023.csv')
data.head()
# Out:
#                     ID LCLAS_NM MLSFC_NM    POI_ID POI_NM  BHF_NM  ASSTN_NM  \
# 0  KCMCDPO23N000073705       장소       카페  18891936   엘가커피   분당야탑점       NaN
# 1  KCMCDPO23N000073706       장소       카페  18891937   엘가커피     안산점       NaN
# 2  KCMCDPO23N000073707       장소       카페  18891938   엘가커피  과학기술대점       NaN
# 3  KCMCDPO23N000073708       장소       카페  18891939   엘가커피     대치점       NaN
# 4  KCMCDPO23N000073709       장소       카페  18891940   엘가커피    동대문점       NaN
#
#    CL_CD   CL_NM                  PNU  ...    RDNMADR_CD RDNMADR_NM BULD_NO  \
# 0  80202  카페(도심)  4113510700103660007  ...  4.113543e+11   야탑로105번길       7
# 1  80202  카페(도심)  4127310100105390001  ...  4.127332e+11        고잔로     102
# 2  80202  카페(도심)  1135010300102080018  ...  1.135030e+11        공릉로     208
# 3  80202  카페(도심)  1168010600109070008  ...  1.168031e+11        역삼로     413
# 4  80202  카페(도심)  1114016400100380000  ...  1.114041e+11     다산로35길      14
#
# ...

# %%
data['Latitude'] = data['LC_LA']
data['Longitude'] = data['LC_LO']
final_data = pd.concat([final_data, data[['Latitude', 'Longitude']]])
final_data
# Out:
#          Latitude   Longitude
# 0       37.759655  128.944649
# 1       38.204664  128.589145
# 2       38.190603  128.529887
# 3       38.174195  128.599662
# 4       38.174254  128.607378
# ...           ...         ...
# 197804  35.227127  128.678774
# 197805  37.400462  126.944957
# 197806  35.815886  127.122613
# 197807  35.237369  128.583837
# 197808  35.235590  128.670183
#
# [259679 rows x 2 columns]

# %% [markdown]
# ### 30 years plus

# %%
data = pd.read_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/30_years_plus_tour.csv')
data.head()
# Out:
#     Latitude   Longitude
# 0  37.562670  126.925797
# 1  37.560073  126.925261
# 2  37.549705  126.922747
# 3  37.552963  126.922117
# 4  37.545517  126.939504

# %%
final_data = pd.concat([final_data, data])
final_data
# Out:
#       Latitude   Longitude
# 0    37.759655  128.944649
# 1    38.204664  128.589145
# 2    38.190603  128.529887
# 3    38.174195  128.599662
# 4    38.174254  128.607378
# ..         ...         ...
# 263  37.563002  126.972907
# 264  37.571598  126.997025
# 265  37.542942  126.946997
# 266  37.562385  126.974488
# 267  37.570312  127.005866
#
# [259947 rows x 2 columns]

# %%
final_data = final_data.reset_index(drop = True)
final_data
# Out:
#          Latitude   Longitude
# 0       37.759655  128.944649
# 1       38.204664  128.589145
# 2       38.190603  128.529887
# 3       38.174195  128.599662
# 4       38.174254  128.607378
# ...           ...         ...
# 259942  37.563002  126.972907
# 259943  37.571598  126.997025
# 259944  37.542942  126.946997
# 259945  37.562385  126.974488
# 259946  37.570312  127.005866
#
# [259947 rows x 2 columns]

# %%
final_data.to_csv('/content/drive/MyDrive/DSL/EDA/예시 데이터/서울시 관광 데이터/Nearby_Final.csv')
